# %% [markdown]
# <a href="https://colab.research.google.com/github/Palakdubeyy/Foundation-of-Data-Science/blob/main/Matplotlib_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.7.1

# %% [markdown]
# Information regarding file handling you can refer the following link:
#
# https://www.w3schools.com/python/python_file_handling.asp

# %%
# Creating File
# f = open('myfile.txt','x')

# Open file in write mode
f = open('myfile.txt','w')

# Overwrite the content inside the file because the file is open in the write mode
f.write('Hello everyone, I am Oshank Agrawal.')

# Close the file
f.close()

# Open the file in read mode
f = open('myfile.txt','r')

# Read the content of file
pd = f.read()

# Print the content of the file
print(pd)

# Close the file
f.close()

print()

# Again open the same file in write mode
f = open('myfile','w')

# Overwrite the content inside the file because the file is open in the write mode
f.write('I currently study in Samrat Ashok Technological Institute Vidisha M.P.')

# Close the file
f.close()

# Again open the same file in read mode
f = open('myfile','r')

# Read the new content of the file
file = f.read()

# Print the new content of the file
print(file)

# Close the file
f.close()

print()

# Again open the file file in append mode
f = open('myfile','a')

# Append the content of the file
f.write('\nI belong from Mathura.')

# close the file
f.close()

# Again open the file in read mode
f = open('myfile','r')

# Read the new content of the file
data = f.read()

# Print the new content of the file
print(data)

# Finally close the file
f.close()
# Out:
# Hello everyone, I am Oshank Agrawal.
#
# I currently study in Samrat Ashok Technological Institute Vidisha M.P.
#
# I currently study in Samrat Ashok Technological Institute Vidisha M.P.
# I belong from Mathura.

# %%
# Creating File
# f = open('mydata.txt','x')

# Open file in write mode
f = open('mydata.txt','w')

# Overwrite the content inside the file because the file is open in the write mode
f.write('xvalues  yvalues')
f.write('\n')
f.write('1  2')
f.write('\n')
f.write('2  4')
f.write('\n')
f.write('3  1')

# Close the file
f.close()

# Open the file in read mode
f = open('mydata.txt','r')

# Read the file line by line
pd = f.readlines()

# Print the content of the file
print(pd)

print()

# Print lines of the file within the range
print(pd[1:3])

# Close the file
f.close()
# Out:
# ['xvalues  yvalues\n', '1  2\n', '2  4\n', '3  1']
#
# ['1  2\n', '2  4\n']

# %% [markdown]
# #Exercise

# %% [markdown]
# **Question 01: Write a Python program to draw a line using given axis values taken from a text file, with suitable label in the x axis, y axis and a title.**
#
# Test Data: test.txt
#
# 1 2
#
# 2 4
#
# 3 1

# %%
import numpy as np
import matplotlib.pyplot as plt

file = open('/content/drive/MyDrive/Data/Matplotlib Exercise Q1.txt','r')
file.readline()

test1  = []
test2 = []

for row in file:
  row = row.split("\t")
  test1.append(int(row[0]))
  test2.append(int(row[1].strip("\n")))
# x = np.array(test1)
# y = np.array(test2)


plt.plot(test1,test2)
plt.show()
# print(test1)
# print(test2)
file.close()

# %% [markdown]
# **Question 02:-** Write a Python program to draw line charts of the financial data of Alphabet Inc. between October 3, 2016 to October 7, 2016.
#
# Sample Financial data (Matplotlib Exercise Q2.csv):

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("/content/drive/MyDrive/Data/Matplotlib Exercise Q2.csv")

line1=data['Open']
line2=data['High']
line3=data['Low']
line4=data['Close']
# print(line1)
# print(line2)
# print(line3)
# print(line4)

y=data['Date']

plt.plot(line1,y)
plt.plot(line2,y)
plt.plot(line3,y)
plt.plot(line4,y)

plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Question 03:-** Write a Python program to plot two or more lines with different styles.

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.array([10,20,30])
y=np.array([40,10,30])
y1=np.array([20,40,10])

plt.plot(x,y,linestyle='dotted',color='purple')
plt.plot(x,y1,linestyle='-',color='red')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Plot with two or more lines with different styles')
plt.show()

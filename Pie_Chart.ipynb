# %% [markdown]
# <a href="https://colab.research.google.com/github/Palakdubeyy/Foundation-of-Data-Science/blob/main/Pie_Chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Representation by Pie Chart**

# %% [markdown]
# Pie chart is a type of graph that involves a structural graphic representation of nnumerical proportion.
#
# It can be replaced in most cases by other plots like a bar chart, box plot, dot plot, etc.
#
# It is shown that it is difficult to compare the different section of a given pie chart.
#
# It is also difficult to compare data across different pie charts.

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
plt.axhline(0,color='black',alpha=0.5)
plt.axvline(0,color='black',alpha=0.5)
plt.pie(y)
plt.show()

# %% [markdown]
# By default the plotting of the first wedge starts from the x-axis and moves counterclockwise:

# %% [markdown]
# # Labels

# %% [markdown]
# Add labels to the pie chart with the labels parameter.
#
# The labels parameter must be an array with one label for each wedge:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.axhline(0,color='black',alpha=0.5)
plt.axvline(0,color='black',alpha=0.5)

plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# # Start Angle

# %% [markdown]
# As mentioned the default start angle is at the x-axis, but you can change the start angle by specifying a startangle parameter.
#
# The startangle parameter is defined with an angle in degrees, default angle is 0:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.axhline(0,color='black',alpha=0.5)
plt.axvline(0,color='black',alpha=0.5)

plt.pie(y, labels = mylabels, startangle = 60)
plt.show()

# %% [markdown]
# # Explode

# %% [markdown]
# Maybe you want one of the wedges to stand out? The explode parameter allows you to do that.
#
# The explode parameter, if specified, and not None, must be an array with one value for each wedge.
#
# Each value represents how far from the center each wedge is displayed:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0.1, 0]

plt.axhline(0,color='black',alpha=0.5)
plt.axvline(0,color='black',alpha=0.5)

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# Here **Apple** section is 0.2 unit far away from the center and **Cherries** Section is also 0.1 unit far away from center while **Banana** and **Dates** are on its original position.

# %% [markdown]
# # Shadow

# %% [markdown]
# Add a shadow to the pie chart by setting the shadows parameter to True:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.axhline(0,color='black',alpha=0.5)
plt.axvline(0,color='black',alpha=0.5)

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %% [markdown]
# # Colors

# %% [markdown]
# You can set the color of each wedge with the colors parameter.
#
# The colors parameter, if specified, must be an array with one value for each wedge:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["red", "hotpink", "b", "#4CAF50"]

plt.axhline(0,color='black',alpha=1)
plt.axvline(0,color='black',alpha=1)

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# You can use Hexadecimal color values, any of the 140 supported color names, or one of these shortcuts:
#
# 'r' - Red
# 'g' - Green
# 'b' - Blue
# 'c' - Cyan
# 'm' - Magenta
# 'y' - Yellow
# 'k' - Black
# 'w' - White

# %% [markdown]
# # Legend

# %% [markdown]
# To add a list of explanation for each wedge, use the legend() function:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.axhline(0,color='black',alpha=0.5)
plt.axvline(0,color='black',alpha=0.5)

plt.pie(y, labels = mylabels)
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# # Legend With Header

# %% [markdown]
# To add a header to the legend, add the title parameter to the legend function.

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.axhline(0,color='black',alpha=0.5)
plt.axvline(0,color='black',alpha=0.5)

plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:",bbox_to_anchor=(0,1))
plt.show()

# %% [markdown]
# # Draw the pie charts with read the data from the CSV File

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Read csv file into pandas
data=pd.read_csv(r"/content/drive/MyDrive/Data/AIADS.csv")

# Create the dataframe
df=pd.DataFrame(data)

# Extracting the attribute from the dataframe
name = list(df["STUDENT NAME"].head(10))
marks = df["final percentage"].head(10)

y=np.array(marks)
plt.pie(y,labels=name)
plt.legend(title = "Four Fruits:",bbox_to_anchor=(1,0))
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Read csv file into pandas
data=pd.read_csv(r"/content/drive/MyDrive/Data/AIADS.csv")

# Create the dataframe
df=pd.DataFrame(data)
df1 = df[['STUDENT NAME', 'final percentage']]
df2=df1.iloc[30:41]
# Extracting the attribute from the dataframe
name = list(df2["STUDENT NAME"])
marks = df2["final percentage"]

y=np.array(marks)
plt.pie(y,labels=name)
plt.legend(title = "Students Name:",bbox_to_anchor=(1,0))
plt.show()
